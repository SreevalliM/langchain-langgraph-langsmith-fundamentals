# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import httpx
from langchain_groq import ChatGroq

# Disable SSL verification to work around corporate proxy/firewall
client = httpx.Client(verify=False)
llm = ChatGroq(model="llama-3.3-70b-versatile", temperature=0, http_client=client)

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=llm,
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='bb468772-bd63-4267-b882-e3ef1d2f9c5c'),
#               AIMessage(content="I don't have any information about your personal preferences, including your favourite colour. I'm a large language model, I don't have the ability to know or recall individual user preferences. Each time you interact with me, it's a new conversation and I don't retain any information from previous conversations. If you'd like to share your favourite colour with me, I'd be happy to chat with you about it!", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 84, 'prompt_tokens': 41, 'total_tokens': 125, 'completion_time': 0.185872248, 'completion_tokens_details': None, 'prompt_time': 0.001954, 'prompt_tokens_details': None, 'queue_time': 0.04837072, 'total_time': 0.187826248}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cc412-9d18-71b1-a133-81c0cb93dc79-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 84, 'total_tokens': 125})]}

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model=llm,
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='c5e28f0a-4e55-4a14-8ce1-732229fcd6ba'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'addd408v0', 'function': {'arguments': '{}', 'name': 'get_favourite_colour'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 267, 'total_tokens': 277, 'completion_time': 0.036603387, 'completion_tokens_details': None, 'prompt_time': 0.013675417, 'prompt_tokens_details': None, 'queue_time': 0.161078232, 'total_time': 0.050278804}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cc413-6de0-7942-b23e-3a9b7f2b0f05-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'addd408v0', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 267, 'output_tokens': 10, 'total_tokens': 277}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='9c3b6e9d-3e7e-45ed-bace-6a5162ddb534', tool_call_id='addd408v0'),
#               AIMessage(content='Your favourite colour is blue.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 289, 'total_tokens': 296, 'completion_time': 0.01723616, 'completion_tokens_details': None, 'prompt_time': 0.015276779, 'prompt_tokens_details': None, 'queue_time': 0.048767982, 'total_time': 0.032512939}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cc413-6f16-77c1-a833-6f2a227b8842-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 289, 'output_tokens': 7, 'total_tokens': 296})]}
# /Users/L107127/Library/CloudStorage/OneDrive-EliLillyandCompany/Desktop/Foundation-Introduction-to-LangGraph---Python/lc-academy-env/lib/python3.12/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='70877b15-2a0e-4560-b42f-6c9ea7a6a02c'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'dykt01n31', 'function': {'arguments': '{}', 'name': 'get_favourite_colour'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 267, 'total_tokens': 277, 'completion_time': 0.035954555, 'completion_tokens_details': None, 'prompt_time': 0.013017088, 'prompt_tokens_details': None, 'queue_time': 0.048880562, 'total_time': 0.048971643}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cc413-8be6-72b0-98d7-cf7a63b45d8b-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'dykt01n31', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 267, 'output_tokens': 10, 'total_tokens': 277}),
#               ToolMessage(content='green', name='get_favourite_colour', id='e6831915-2159-4e54-8b0c-610283439007', tool_call_id='dykt01n31'),
#               AIMessage(content='Your favourite colour is green.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 289, 'total_tokens': 296, 'completion_time': 0.017495165, 'completion_tokens_details': None, 'prompt_time': 0.014490061, 'prompt_tokens_details': None, 'queue_time': 0.048670429, 'total_time': 0.031985226}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cc413-8ca5-7271-ba24-00321c9a3ae2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 289, 'output_tokens': 7, 'total_tokens': 296})]}
# /Users/L107127/Library/CloudStorage/OneDrive-EliLillyandCompany/Desktop/Foundation-Introduction-to-LangGraph---Python/lc-academy-env/lib/python3.12/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
