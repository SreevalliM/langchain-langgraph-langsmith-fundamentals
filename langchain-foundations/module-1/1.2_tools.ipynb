# %% [markdown]
# ## Tool definition

# %%
import httpx
from langchain_groq import ChatGroq

# Disable SSL verification to work around corporate proxy/firewall
client = httpx.Client(verify=False)
llm = ChatGroq(model="llama-3.3-70b-versatile", temperature=0, http_client=client)

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=llm,
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is 21.61018278497431.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='7d6e4b00-ca25-4732-9801-b1dceb6e08a1'),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'chcmh490v', 'function': {'arguments': '{"x":467}', 'name': 'square_root'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 243, 'total_tokens': 257, 'completion_time': 0.051572074, 'completion_tokens_details': None, 'prompt_time': 0.012314093, 'prompt_tokens_details': None, 'queue_time': 0.047882707, 'total_time': 0.063886167}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cbf73-c81a-7c00-b7f4-23e707c4d1ad-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'chcmh490v', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 243, 'output_tokens': 14, 'total_tokens': 257}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='e18b1868-3dca-4840-9435-6c5c56cca2f4', tool_call_id='chcmh490v'),
#  AIMessage(content='The square root of 467 is 21.61018278497431.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 274, 'total_tokens': 291, 'completion_time': 0.033024869, 'completion_tokens_details': None, 'prompt_time': 0.025425567, 'prompt_tokens_details': None, 'queue_time': 0.050469696, 'total_time': 0.058450436}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cbf73-c936-73c3-b800-a23de9054d92-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 274, 'output_tokens': 17, 'total_tokens': 291})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'chcmh490v', 'type': 'tool_call'}]
