# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import httpx
from langchain_groq import ChatGroq

# Disable SSL verification to work around corporate proxy/firewall
client = httpx.Client(verify=False)
llm = ChatGroq(model="llama-3.3-70b-versatile", temperature=0, http_client=client)

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from mistune import markdown
from IPython.display import HTML

agent = create_agent(model=llm)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

HTML(markdown(response['messages'][1].content))
# Out:
# <p>The Moon does not have a capital city. The Moon is a natural satellite that orbits the Earth, and it does not have a government or permanent human settlements. While there have been several manned missions to the Moon in the past, no human has ever established a permanent residence or government on the Moon. So, there is no capital city to speak of!</p>

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=llm,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# I'm happy to create a capital city for the moon. Let's call it... **Lunaria**.
#
# Lunaria is a futuristic, self-sustaining city that serves as the capital of the lunar government. Located in the southern hemisphere of the moon, Lunaria is nestled within the vast, dark expanse of the South Pole-Aitken basin. The city's strategic location provides access to abundant resources, including helium-3, a rare isotope used as fuel for nuclear fusion.
#
# **Architecture:**
# Lunaria's architecture is a blend of functionality and aesthetics. The city's core is a large, domed structure that encloses a habitable environment, protecting its inhabitants from the harsh lunar surface conditions. The dome is composed of a durable, transparent material that allows for natural light to filter in during the day and offers breathtaking views of the Earth from the city's observation decks.
#
# The city's infrastructure is divided into six main districts, each with its unique character and purpose:
#
# 1. **The Spire of Lunaria**: The city's central hub, housing the government, administrative offices, and the lunar council.
# 2. **The Helix**: A district dedicated to scientific research, innovation, and development, featuring state-of-the-art laboratories and research facilities.
# 3. **The Arcadia**: A residential area with lush, verdant parks and gardens, providing a tranquil oasis for the city's inhabitants.
# 4. **The Nova Haven**: A bustling commercial district, featuring shops, restaurants, and entertainment venues.
# 5. **The Aurora**: A district focused on education, arts, and culture, with institutions, museums, and performance venues.
# 6. **The Terraverde**: A district dedicated to sustainable living, featuring green spaces, urban farms, and eco-friendly infrastructure.
#
# **Transportation:**
# Lunaria is connected to the rest of the moon via a network of vacuum-sealed tunnels and tubes, allowing for efficient and safe transportation. The city also has a spaceport, facilitating travel to and from Earth, as well as other destinations in the solar system.
#
# **Inhabitants:**
# Lunaria is home to a diverse population of approximately 50,000 inhabitants, including scientists, engineers, entrepreneurs, artists, and government officials. The city's residents enjoy a high standard of living, with access to advanced healthcare, education, and entertainment facilities.
#
# **Challenges and Opportunities:**
# As the capital of the moon, Lunaria faces unique challenges, such as managing resources, mitigating the effects of lunar regolith, and addressing the psychological impacts of living in a low-gravity, isolated environment. However, the city's inhabitants are driven by a sense of wonder, curiosity, and innovation, making Lunaria a hub for progress, discovery, and exploration in the solar system.
#
# Welcome to Lunaria, the shining capital of the moon!

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=llm,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The capital of the moon is Lunaria City, also known as New Tranquility. It's a bustling metropolis located in the southern hemisphere of the moon, near the crater of Shackleton. Lunaria City is the center of lunar politics, commerce, and innovation, and is home to the Lunar Union's government and the famous Moonwalk University. The city is a marvel of modern engineering, with towering domes and habitats that protect its inhabitants from the harsh lunar environment.

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=llm,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaria
#
# Location: Southern hemisphere of the Moon, near the crater of Shackleton
#
# Vibe: Futuristic Oasis
#
# Economy: The main industries in Lunaria are Helium-3 mining, Space Tourism, and Advanced Robotics manufacturing, with a growing sector in Lunar-based Renewable Energy.

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=llm,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunar Haven', location='The Moon', vibe='futuristic', economy='space-based')

# %%
response["structured_response"].name
# Out:
# 'Lunar Haven'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunar Haven is a city located at The Moon
